# %% [markdown]
# <a href="https://colab.research.google.com/github/teyoon1105/DataScience2024/blob/main/%ED%83%9C%EC%96%91%EA%B4%91%EB%B0%9C%EC%A0%84%EC%86%8C%EC%9C%84%EC%B9%98_%EC%8B%9C%EA%B0%81%ED%99%94%ED%95%98%EA%B8%B0_%EC%B2%98%EC%9D%8C%EB%B6%80%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 한굴 나눔폰트 설치하기
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# ^C
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# ...

# %%
# 한글 나눔고딕 설정하기
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
csvPath = '/content/drive/MyDrive/제주특별자치도_태양광발전소현황_20220630.csv의 사본'

# %%
import pandas as pd
df = pd.read_csv(csvPath, encoding='cp949')
df.head()
# Out:
#    행정시  읍면동        허가일자            상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 0  제주시  구좌읍  1998-06-10  행원풍력발전단지(1차)    3480.0  사업개시  2000-04-05  2022-06-30
# 1  제주시  회천동  2002-12-09     파낙스에너지(주)    1000.0  사업개시  2002-12-18  2022-06-30
# 2  제주시  한경면  2003-04-14      한경풍력 1단계    6000.0  사업개시  2004-02-28  2022-06-30
# 3  제주시  한경면  2005-04-04      신창풍력발전단지    1700.0  사업개시  2006-03-03  2022-06-30
# 4  제주시  구좌읍  2005-08-30     제주월정풍력발전소    1500.0  사업개시  2006-07-20  2022-06-30

# %%
df.tail()
# Out:
#        행정시  읍면동        허가일자           상호  설비용량(KW)   상태 사업개시일     데이터기준일자
# 2143   제주시  한경면  2022-06-08    민재 태양광발전소      99.6  인허가   NaN  2022-06-30
# 2144   제주시  한림읍  2022-06-08  효일4호 태양광발전소      99.0  인허가   NaN  2022-06-30
# 2145   제주시  한림읍  2022-06-08  효일3호 태양광발전소      99.0  인허가   NaN  2022-06-30
# 2146   제주시  한림읍  2022-06-08  효일5호 태양광발전소      99.0  인허가   NaN  2022-06-30
# 2147  서귀포시  성산읍  2022-06-21   한라2호소수력발전소     210.0  인허가   NaN  2022-06-30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148 entries, 0 to 2147
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   행정시       2148 non-null   object
#  1   읍면동       2148 non-null   object
#  2   허가일자      2148 non-null   object
#  3   상호        2148 non-null   object
#  4   설비용량(KW)  2148 non-null   float64
#  5   상태        2148 non-null   object
#  6   사업개시일     1571 non-null   object
#  7   데이터기준일자   2148 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 134.4+ KB

# %%
# 결측치가 있는 행은 삭제한다(미공사일테니까)
df.dropna(inplace = True)
df.reset_index(drop = True, inplace = True)
df.head()
# Out:
#    행정시  읍면동        허가일자            상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 0  제주시  구좌읍  1998-06-10  행원풍력발전단지(1차)    3480.0  사업개시  2000-04-05  2022-06-30
# 1  제주시  회천동  2002-12-09     파낙스에너지(주)    1000.0  사업개시  2002-12-18  2022-06-30
# 2  제주시  한경면  2003-04-14      한경풍력 1단계    6000.0  사업개시  2004-02-28  2022-06-30
# 3  제주시  한경면  2005-04-04      신창풍력발전단지    1700.0  사업개시  2006-03-03  2022-06-30
# 4  제주시  구좌읍  2005-08-30     제주월정풍력발전소    1500.0  사업개시  2006-07-20  2022-06-30

# %%
df.tail()
# Out:
#        행정시  읍면동        허가일자           상호  설비용량(KW)    상태       사업개시일  \
# 1566  서귀포시  안덕면  2021-04-19     썬 태양광발전소    182.00  사업개시  2022-01-03
# 1567  서귀포시  안덕면  2021-04-19    청춘 태양광발전소    662.48  사업개시  2022-01-03
# 1568  서귀포시  표선면  2021-04-21  제주덕암 태양광발전소     99.18  사업개시  2022-01-03
# 1569  서귀포시  안덕면  2021-08-03   태양7호태양광발전소    198.88  사업개시  2021-12-10
# 1570   제주시  구좌읍  2021-09-15     흥산태양광발전소    999.63  사업개시  2022-04-25
#
#          데이터기준일자
# 1566  2022-06-30
# 1567  2022-06-30
# 1568  2022-06-30
# 1569  2022-06-30
# 1570  2022-06-30

# %%
df[df['상태'] != '사업개시']
# Out:
#       행정시  읍면동        허가일자         상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 6     제주시  한경면  2006-08-11  탐라해상풍력발전소   30000.0  공사진행  2017-09-16  2022-06-30
# 29   서귀포시  성산읍  2008-02-28   성산풍력 1단계   12000.0  공사진행  2009-03-30  2022-06-30
# 485   제주시  한경면  2016-11-16     성용유화발전     750.0   인허가  2016-11-16  2022-06-30

# %%
editList = df[df['상태'] != '사업개시'].index

for index in editList:
    df.loc[index, '상태'] = '사업개시'

# %%
csvPath2 = '/content/drive/MyDrive/제주특별자치도_신재생에너지발전시설현황_20221116.csv의 사본'

# %%
df2 = pd.read_csv(csvPath2, encoding='cp949')
df2.head()
# Out:
#          허가일자          상호  설비용량(KW)              설치장소 원동력종류       사업개시일  \
# 0  2019-05-22   북촌서모풍력발전소    3000.0   제주특별자치도 제주시 조천읍    풍력  2020-07-31
# 1  2016-12-12  동복리마을풍력발전소    2000.0   제주특별자치도 제주시 구좌읍    풍력  2017-12-01
# 2  2016-10-17     수망풍력발전소   25200.0  제주특별자치도 서귀포시 남원읍    풍력  2020-06-29
# 3  2014-06-13  동복북촌풍력발전단지   30000.0   제주특별자치도 제주시 구좌읍    풍력  2015-08-01
# 4  2014-05-02     상명풍력발전소   21000.0   제주특별자치도 제주시 한림읍    풍력  2016-08-22
#
#       데이터기준일자
# 0  2022-11-16
# 1  2022-11-16
# 2  2022-11-16
# 3  2022-11-16
# 4  2022-11-16

# %%
df2.tail()
# Out:
#             허가일자                      상호  설비용량(KW)              설치장소  원동력종류  \
# 1577  2013-03-12                 주식회사 이웰    2950.0  제주특별자치도 서귀포시 토평동  바이오가스
# 1578  2012-11-27     농업회사법인 주식회사 한라산 바이오     500.0  제주특별자치도 서귀포시 안덕면  바이오가스
# 1579  2010-06-21  (주)농업회사법인 제주축산바이오가스발전소      99.0   제주특별자치도 제주시 한림읍  바이오가스
# 1580  2002-12-09               파낙스에너지(주)    1000.0   제주특별자치도 제주시 회천동  바이오가스
# 1581  2015-05-27          서광산업 신재생에너지발전소    2400.0   제주특별자치도 제주시 애월읍     기타
#
#            사업개시일     데이터기준일자
# 1577  2015-07-21  2022-11-16
# 1578  2015-05-01  2022-11-16
# 1579  2010-08-24  2022-11-16
# 1580  2002-12-18  2022-11-16
# 1581  2015-12-17  2022-11-16

# %%
df2['원동력종류'].unique()
# Out:
# array(['풍력', '태양광', '수력', '바이오가스', '기타'], dtype=object)

# %%
df3 = df2[df2['원동력종류'] == '태양광']

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1547 entries, 24 to 1570
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   허가일자      1547 non-null   object
#  1   상호        1547 non-null   object
#  2   설비용량(KW)  1547 non-null   float64
#  3   설치장소      1547 non-null   object
#  4   원동력종류     1547 non-null   object
#  5   사업개시일     1547 non-null   object
#  6   데이터기준일자   1547 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 96.7+ KB

# %%
df3.reset_index(drop = True, inplace = True)
df3.head()
df3.tail()
# Out:
#             허가일자          상호  설비용량(KW)              설치장소 원동력종류       사업개시일  \
# 1542  2007-02-21  제주에너지 주식회사    200.00  제주특별자치도 서귀포시 성산읍   태양광  2008-09-29
# 1543  2007-02-21  제주에너지 주식회사    200.00   제주특별자치도 제주시 애월읍   태양광  2008-04-18
# 1544  2007-01-05      민솔라에너지     90.72   제주특별자치도 제주시 조천읍   태양광  2007-04-04
# 1545  2006-08-24     오복산전 3호     29.52   제주특별자치도 제주시 한경면   태양광  2006-09-25
# 1546  2006-03-03        오복산전     59.87   제주특별자치도 제주시 한경면   태양광  2006-07-11
#
#          데이터기준일자
# 1542  2022-11-16
# 1543  2022-11-16
# 1544  2022-11-16
# 1545  2022-11-16
# 1546  2022-11-16

# %%
# 설비 용량 총량 계산
df.columns
# Out:
# Index(['행정시', '읍면동', '허가일자', '상호', '설비용량(KW)', '상태', '사업개시일', '데이터기준일자'], dtype='object')

# %%
df3['설비용량(KW)'].sum()
# Out:
# 509086.72

# %%
print(df3['설치장소'].unique())
print(df3['설치장소'].nunique())
# Out:
# ['제주특별자치도 제주시 구좌읍' '제주특별자치도 서귀포시 안덕면' '제주특별자치도 서귀포시 표선면'
#  '제주특별자치도 서귀포시 성산읍' '제주특별자치도 서귀포시 법환동' '제주특별자치도 서귀포시 대정읍'
#  '제주특별자치도 제주시 한림읍' '제주특별자치도 서귀포시 남원읍' '제주특별자치도 서귀포시 상예동'
#  '제주특별자치도 서귀포시 회수동' '제주특별자치도 제주시 조천읍' '제주특별자치도 제주시 도남동' '제주특별자치도 제주시 애월읍'
#  '제주특별자치도 서귀포시 토평동' '제주특별자치도 서귀포시 강정동' '제주특별자치도 서귀포시 중문동'
#  '제주특별자치도 제주시 봉개동' '제주특별자치도 서귀포시 월평동' '제주특별자치도 제주시 용담이동'
#  '제주특별자치도 제주시 일도이동' '제주특별자치도 제주시 회천동' '제주특별자치도 제주시 해안동' '제주특별자치도 서귀포시 호근동'
#  '제주특별자치도 제주시 오라삼동' '제주특별자치도 제주시 한경면' '제주특별자치도 제주시 아라이동'
#  '제주특별자치도 제주시 오라이동' '제주특별자치도 제주시 용강동' '제주특별자치도 제주시 외도일동'
#  '제주특별자치도 제주시 삼양일동' '제주특별자치도 서귀포시 도순동' '제주특별자치도 서귀포시 상효동'
#  '제주특별자치도 서귀포시 서홍동' '제주특별자치도 제주시 이도일동' '제주특별자치도 제주시 오등동'
#  '제주특별자치도 서귀포시 서호동' '제주특별자치도 제주시 영평동' '제주특별자치도 서귀포시 동홍동'
#  '제주특별자치도 서귀포시 하원동' '제주특별자치도 제주시 이호이동' '제주특별자치도 제주시 화북이동'
#  '제주특별자치도 서귀포시 색달동' '제주특별자치도 서귀포시 서귀동' '제주특별자치도 제주시 도련이동'
#  '제주특별자치도 제주시 오라일동' '제주특별자치도 서귀포시 하효동' '제주특별자치도 제주시 도평동'
#  '제주특별자치도 서귀포시 하예동' '제주특별자치도 제주시 노형동' '제주특별자치도 제주시 삼도이동'
# ...

# %%
# 태양광 발전소가 1년간 새로 사업을 시작한 갯수, 발전용량 확인(얼마만큼 발전??)
df_year21 = df3[(df3['사업개시일']>='2021-01-01')&(df3['사업개시일']<='2021-12-31')]
df_year21['설비용량(KW)'].sum()
# Out:
# 108352.51999999999

# %%
df3['설비용량(KW)'].sum()
# Out:
# 509086.72

# %%
# geopy 패키지
# 주소값을 위도와 경도로 변환
# 가입 없이 주소->좌표 변환
from geopy.geocoders import Nominatim

# 주소나 위도, 경도가 중복되지 않은 고유한 정보를
# 리스트에 각각 담아주기 위해 빈 리스트 생성

unique_lat=[]
unique_lng=[]
except_addr=[]

# 주소를 위도와 경도로 변환해 주는 함수
def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    geo = geolocoder.geocode(address)
    # 주소값을 제대로 인식하지 못할때
    # 위도와 경도값을 None값을 리턴한다.
    if geo==None:
        print('주소가 어디인지 인식할 수 없습니다.:{}'.format(address))
        except_addr.append(address)
        return 0, 0
    else:
        return geo.latitude, geo.longitude

# %%
geo = geocoding('제주 제주시 구좌읍')
print(geo)
# Out:
# (33.51662, 126.81055)

# %%
# 데이터프레임 ['설치장소'][경도][위도]
mapaddr_df = df3['설치장소'].unique()

# %%
for addr in mapaddr_df:
    if addr == '제주특별자치도 제주시 삼도이동':
        addr = '제주시 삼도 2동'
    geo = geocoding(addr)
    print(geo)
    unique_lat.append(geo[0])
    unique_lng.append(geo[1])

# mapaddr_df['위도'] = unique_lat
# mapaddr_df['경도'] = unique_lng
# Out:
# (33.51662, 126.81055)
# (33.27688, 126.34925)
# (33.3504543, 126.794049)
# (33.41805, 126.88147)
# (33.24113, 126.51285)
# (33.2218157, 126.2529945)
# (33.39344, 126.26684)
# (33.3076683, 126.6907475)
# (33.26177, 126.38678)
# (33.26549, 126.44363)
# (33.50888, 126.66305)
# (33.4905148, 126.5239964)
# (33.45079, 126.3752)
# (33.2705286, 126.5841149)
# (33.24695, 126.48927)
# (33.262002, 126.4288617)
# (33.484188, 126.5993497)
# (33.24501, 126.46294)
# (33.50742, 126.50615)
# (33.50864, 126.53795)
# (33.4956, 126.61479)
# (33.44899, 126.46036)
# (33.25632, 126.53351)
# (33.49487, 126.50508)
# (33.3305, 126.21066)
# (33.48148, 126.55055)
# (33.47081, 126.50991)
# (33.47017, 126.58934)
# (33.4855847, 126.4284514)
# (33.52345, 126.599)
# (33.2569662, 126.4731036)
# (33.2896254, 126.5945088)
# (33.25965, 126.55175)
# (33.5059, 126.5278)
# (33.46148, 126.53087)
# (33.25759, 126.51916)
# (33.4812, 126.57106)
# (33.26184, 126.56804)
# (33.2626587, 126.4600239)
# (33.498551, 126.4565213)
# ...

# %%
len(df3['설치장소'].unique())
# Out:
# 52

# %%
len(unique_lat)
# Out:
# 52

# %%
map_df = pd.DataFrame({'설치장소':df3['설치장소'].unique(), '위도':unique_lat, '경도':unique_lng})

# %%
map_df
# Out:
#                 설치장소         위도          경도
# 0    제주특별자치도 제주시 구좌읍  33.516620  126.810550
# 1   제주특별자치도 서귀포시 안덕면  33.276880  126.349250
# 2   제주특별자치도 서귀포시 표선면  33.350454  126.794049
# 3   제주특별자치도 서귀포시 성산읍  33.418050  126.881470
# 4   제주특별자치도 서귀포시 법환동  33.241130  126.512850
# 5   제주특별자치도 서귀포시 대정읍  33.221816  126.252994
# 6    제주특별자치도 제주시 한림읍  33.393440  126.266840
# 7   제주특별자치도 서귀포시 남원읍  33.307668  126.690748
# 8   제주특별자치도 서귀포시 상예동  33.261770  126.386780
# 9   제주특별자치도 서귀포시 회수동  33.265490  126.443630
# 10   제주특별자치도 제주시 조천읍  33.508880  126.663050
# 11   제주특별자치도 제주시 도남동  33.490515  126.523996
# 12   제주특별자치도 제주시 애월읍  33.450790  126.375200
# 13  제주특별자치도 서귀포시 토평동  33.270529  126.584115
# 14  제주특별자치도 서귀포시 강정동  33.246950  126.489270
# 15  제주특별자치도 서귀포시 중문동  33.262002  126.428862
# 16   제주특별자치도 제주시 봉개동  33.484188  126.599350
# 17  제주특별자치도 서귀포시 월평동  33.245010  126.462940
# 18  제주특별자치도 제주시 용담이동  33.507420  126.506150
# 19  제주특별자치도 제주시 일도이동  33.508640  126.537950
# ...

# %%
#map_df['설치장소']를 index로 설정
map_df.set_index('설치장소', inplace=True)

# %%
map_df = pd.DataFrame({'설치장소':df3['설치장소'].unique(), '위도':unique_lat, '경도':unique_lng})

# %%
# 지도를 그릴때 사용하는 패키지는 folium

import pandas as pd
import folium

# 지도가 그려질 중심 좌표(대략 제주도의 중심 좌표), 지도를 그릴때 얼마나 줌을 적용할지
jeju_map = folium.Map(location=[33.38, 126.55], zoom_start=11)

for i in range(len(map_df)):
    pos_list = [map_df.iloc[i][0], map_df.iloc[i][1]]
    folium.Marker(pos_list, popup=map_df.index[i]).add_to(jeju_map)

jeju_map.save('jeju.html')
# Out:
# <ipython-input-112-07a092f42839>:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pos_list = [map_df.iloc[i][0], map_df.iloc[i][1]]
