# %% [markdown]
# <a href="https://colab.research.google.com/github/teyoon1105/DataScience2024/blob/main/%EC%84%9C%EC%9A%B8100%EB%85%84%EC%9D%98%EB%82%A0%EC%94%A8%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 한글 폰트 설치, 설정을 위해
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (14.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
# matplotlib 나눔바른고딕제로 폰트 변경하기
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font', family='NanumBarunGothic')

# %%
# 데이터 파일을 가져오기 위해 구글 드라이브 마운트
from google.colab import drive
# 어느 위치에다가 마운트를 할 지
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# 기본이 되는 경로
dataPath = '/content/drive/MyDrive/DataScience/2024 data/'
# 경로 문자열을 더할때

csvPath1= os.path.join(dataPath, 'seoul.csv의 사본')
csvPath2= os.path.join(dataPath, 'seoul2.csv의 사본')
csvPath3= os.path.join(dataPath, 'seoul3.csv의 사본')

# %%
import numpy as np
import pandas as pd

df1 = pd.read_csv(csvPath1, encoding='cp949')
df2 = pd.read_csv(csvPath2, encoding='cp949')
df3 = pd.read_csv(csvPath3, encoding='cp949')

# %%
df1.head()
# Out:
#            날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  1907-10-01  108     13.5      7.9     20.7
# 1  1907-10-02  108     16.2      7.9     22.0
# 2  1907-10-03  108     16.2     13.1     21.3
# 3  1907-10-04  108     16.5     11.2     22.0
# 4  1907-10-05  108     17.6     10.9     25.4

# %%
df1.tail()
# Out:
#                날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 39921  2018-03-24  108      7.6      4.0     13.1
# 39922  2018-03-25  108      9.6      4.6     16.9
# 39923  2018-03-26  108     11.0      5.3     18.1
# 39924  2018-03-27  108     13.3      7.7     20.0
# 39925  2018-03-28  108     14.0      9.4     19.0

# %%
df2.head()
# Out:
#     지점 지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 0  108  서울  2018-03-29      15.4      11.8      21.1
# 1  108  서울  2018-03-30      14.8       9.8      21.9
# 2  108  서울  2018-03-31      14.0       9.3      20.1
# 3  108  서울  2018-04-01      15.6      11.7      18.5
# 4  108  서울  2018-04-02      18.4      14.9      23.7

# %%
df2.tail()
# Out:
#        지점 지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 2318  108  서울  2024-08-02      29.6      28.2      32.5
# 2319  108  서울  2024-08-03      30.2      27.2      34.2
# 2320  108  서울  2024-08-04      31.8      27.3      36.2
# 2321  108  서울  2024-08-05      30.0      26.9      33.7
# 2322  108  서울  2024-08-06      29.5      25.6      33.5

# %%
df3.head()
# Out:
#     지점 지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 0  108  서울  2024-08-06      29.5      25.6      33.5
# 1  108  서울  2024-08-07      29.6      27.2      33.4
# 2  108  서울  2024-08-08      28.5      26.9      31.6
# 3  108  서울  2024-08-09      29.3      25.6      33.6
# 4  108  서울  2024-08-10      30.0      26.4      33.6

# %%
df3.tail()
# Out:
#     지점 지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)
# 1  108  서울  2024-08-07      29.6      27.2      33.4
# 2  108  서울  2024-08-08      28.5      26.9      31.6
# 3  108  서울  2024-08-09      29.3      25.6      33.6
# 4  108  서울  2024-08-10      30.0      26.4      33.6
# 5  108  서울  2024-08-11      30.8      27.8      34.4

# %%
df1.columns = ['일시', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
df1['지점명'] = '서울'
df1.head()
# Out:
#            일시   지점  평균기온(℃)  최저기온(℃)  최고기온(℃) 지점명
# 0  1907-10-01  108     13.5      7.9     20.7  서울
# 1  1907-10-02  108     16.2      7.9     22.0  서울
# 2  1907-10-03  108     16.2     13.1     21.3  서울
# 3  1907-10-04  108     16.5     11.2     22.0  서울
# 4  1907-10-05  108     17.6     10.9     25.4  서울

# %%
df1 = df1[['지점', '지점명','일시','평균기온(℃)', '최저기온(℃)', '최고기온(℃)']]
df1.head()
# Out:
#     지점 지점명          일시  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  108  서울  1907-10-01     13.5      7.9     20.7
# 1  108  서울  1907-10-02     16.2      7.9     22.0
# 2  108  서울  1907-10-03     16.2     13.1     21.3
# 3  108  서울  1907-10-04     16.5     11.2     22.0
# 4  108  서울  1907-10-05     17.6     10.9     25.4

# %%
df1.columns=['지점', '지점명','일시','평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
df2.columns=['지점', '지점명','일시','평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
df3.columns=['지점', '지점명','일시','평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
# df1, df2, df3를 concat
df = pd.concat([df1, df2, df3])
df.head()
# Out:
#     지점 지점명          일시  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  108  서울  1907-10-01     13.5      7.9     20.7
# 1  108  서울  1907-10-02     16.2      7.9     22.0
# 2  108  서울  1907-10-03     16.2     13.1     21.3
# 3  108  서울  1907-10-04     16.5     11.2     22.0
# 4  108  서울  1907-10-05     17.6     10.9     25.4

# %%
df.tail()
# Out:
#     지점 지점명          일시  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 1  108  서울  2024-08-07     29.6     27.2     33.4
# 2  108  서울  2024-08-08     28.5     26.9     31.6
# 3  108  서울  2024-08-09     29.3     25.6     33.6
# 4  108  서울  2024-08-10     30.0     26.4     33.6
# 5  108  서울  2024-08-11     30.8     27.8     34.4

# %%
# 결측치가 있는 기간이 있는데 기간이 어떻게 되는가
# 1907년 2024년 동안 평균기온이 상승하는가? 연평균기온 가지고 비교하자
# 연평균 기온 구하기 : 월평균을 구하고 연평균을구한다
#
# 상승한다면 얼마나 상승하는가

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42255 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지점       42255 non-null  int64
#  1   지점명      42255 non-null  object
#  2   일시       42255 non-null  object
#  3   평균기온(℃)  41499 non-null  float64
#  4   최저기온(℃)  41497 non-null  float64
#  5   최고기온(℃)  41497 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 3.3+ MB

# %%
# 데이터 전처리시에 가장 먼저 할 것은 결측치를 다루는 일이다.
# 일시 컬럼을 3개의 컬럼을 만들어서
# 년도/월/일 로 나눠서
# 년 data
# 월 data 를 넣는다.
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#      ...
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: 일시, Length: 42255, dtype: bool

# %%
# 1907년 삭제
# 1950년 삭제
# 1951년 삭제
# 1952년 삭제
# 1953년 삭제


df2 = df.copy()
for year in df['일시']:
    if year[0:4] == '1907':
        df2 = df2.drop(df2[df2['일시'] == year].index)
    elif year[0:4] == '1950':
        df2 = df2.drop(df2[df2['일시'] == year].index)
    elif year[0:4] == '1951':
        df2 = df2.drop(df2[df2['일시'] == year].index)
    elif year[0:4] == '1952':
        df2 = df2.drop(df2[df2['일시'] == year].index)
    elif year[0:4] == '1953':
        df2 = df2.drop(df2[df2['일시'] == year].index)
    elif year[0:4] == '2024':
        df2 = df2.drop(df2[df2['일시'] == year].index)
    else:
        pass
# 왜 작동하는 지 모르겠는 코드

# 나머지 년도의 모든 일 평균온도의 합을 구하고
# 그 값을 365로 나눈 년 평균온도를 구하라

df2.reset_index(drop=True, inplace=True)
df2.head()

# 년 평균온도 column을 만들고
# 각 년도에 해당하는 년 평균온도 값을 value 값으로 넣는다
# x축은 각년, y축은 년평균온도로 산점도를 그려본다
# Out:
#     지점 지점명          일시  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  108  서울  1908-01-01     -5.9     -9.1     -1.3
# 1  108  서울  1908-01-02     -7.7    -13.9     -3.0
# 2  108  서울  1908-01-03     -6.2    -10.8     -2.9
# 3  108  서울  1908-01-04     -7.5    -12.8     -1.7
# 4  108  서울  1908-01-05     -4.8    -11.3     -0.1

# %%
df2.reset_index(drop=True, inplace=True)
df2.head()
# Out:
#     지점 지점명          일시  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  108  서울  1908-01-01     -5.9     -9.1     -1.3
# 1  108  서울  1908-01-02     -7.7    -13.9     -3.0
# 2  108  서울  1908-01-03     -6.2    -10.8     -2.9
# 3  108  서울  1908-01-04     -7.5    -12.8     -1.7
# 4  108  서울  1908-01-05     -4.8    -11.3     -0.1

# %%
df2.tail()
# Out:
#         지점 지점명          일시  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 40592  108  서울  2023-12-27      1.5     -2.8      6.8
# 40593  108  서울  2023-12-28      1.2     -1.7      4.4
# 40594  108  서울  2023-12-29      1.3     -1.5      4.6
# 40595  108  서울  2023-12-30      0.6     -0.9      2.1
# 40596  108  서울  2023-12-31      2.1      0.6      4.3

# %%
79182 % 365
# Out:
# 342

# %%
df.loc[df['평균기온(℃)'].isnull()]['일시']
# 1950년 9월 1일 부터 1953년 11월 30일의 평균 기온 data가 NaN되어있다
# Out:
# 15676    1950-09-01
# 15677    1950-09-02
# 15678    1950-09-03
# 15679    1950-09-04
# 15680    1950-09-05
#             ...
# 16427    1953-11-26
# 16428    1953-11-27
# 16429    1953-11-28
# 16430    1953-11-29
# 16431    1953-11-30
# Name: 일시, Length: 756, dtype: object

# %%
df.loc[df['최저기온(℃)'].isnull()]['일시']
# 1950년 9월 1일 부터 1953년 11월 30일의 데이터가 누락되어있으며, 1967년 2월 19일, 2022년 8월 8일의 데이터도 누락되어있다
# Out:
# 15676    1950-09-01
# 15677    1950-09-02
# 15678    1950-09-03
# 15679    1950-09-04
# 15680    1950-09-05
#             ...
# 16429    1953-11-28
# 16430    1953-11-29
# 16431    1953-11-30
# 21260    1967-02-19
# 1593     2022-08-08
# Name: 일시, Length: 758, dtype: object

# %%
df.loc[df['최고기온(℃)'].isnull()]['일시']
# 1950년 9월 1일, 1953년 11월 30일 까지의 데이터가 누락되어 있으며, 1967년 2월 19일, 2917년 10월 12일의 데이터가 누락되어있다.
# Out:
# 15676    1950-09-01
# 15677    1950-09-02
# 15678    1950-09-03
# 15679    1950-09-04
# 15680    1950-09-05
#             ...
# 16429    1953-11-28
# 16430    1953-11-29
# 16431    1953-11-30
# 21260    1967-02-19
# 39758    2017-10-12
# Name: 일시, Length: 758, dtype: object

# %%
for text in df['일시']:
    sum = 0
    if text[0:4] == '1907':
        sum += int(df[])
# Out:
#   File "<ipython-input-25-717244c5f48a>", line 4
#     sum += int(df[])
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df['평균기온(℃)'].dropna()
